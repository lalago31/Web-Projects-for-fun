# %% [markdown]
# ## Get house listings in NYC through Craiglist HTML

# %%
import requests
import urllib
from bs4 import BeautifulSoup

# %%
city='New York City'
url='https://newyork.craigslist.org/search/hhh?sort=rel&query={}'.format(city.replace(' ','+'))
url
# Out:
# 'https://newyork.craigslist.org/search/hhh?sort=rel&query=New+York+City'

# %%
https://newyork.craigslist.org/search/rea?query=long+island+city+apartment&availabilityMode=0&sale_date=all+dates

# %% [markdown]
# ### Use requests to call the html webpage, and beautifulsoup to parse the text

# %%
source=requests.get(url).text
soup=BeautifulSoup(source,'lxml')
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    ﻿
#    <!DOCTYPE html>
#   </p>
#   <title>
#    new york housing "New York City" - craigslist
#   </title>
#   <meta content='new york housing "New York City" - craigslist' name="description"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <link href="https://newyork.craigslist.org/search/hhh" rel="canonical"/>
#   <link href="https://newyork.craigslist.org/search/hhh?format=rss&amp;query=New%20York%20City&amp;sort=rel" rel="alternate" title='RSS feed for craigslist | new york housing "New York City" - craigslist' type="application/rss+xml"/>
#   <link href="https://newyork.craigslist.org/search/hhh?s=120&amp;query=New%20York%20City&amp;sort=rel" rel="next"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <link href="//www.craigslist.org/styles/cl.css?v=38ee99f34dcd77a615cd2d3c32114559" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//www.craigslist.org/styles/search.css?v=84cf86bc094026e12fa066bbbab154ac" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//www.craigslist.org/styles/leaflet.css?v=33e3dd14c7deed955c83b6927c5e1f07" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//www.craigslist.org/styles/tocsmaps.css?v=d3ac18e00752d21e15dc93be93a12756" media="all" rel="stylesheet" type="text/css"/>
#   <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">
# <![endif]-->
#   <script type="text/javascript">
#    <!--
# var areaCountry = "US";
# var areaID = "3";
# var areaRegion = "NY";
# var catAbb = "hhh";
# var countOfTotalText = "image {count} of {total}";
# var currencySymbol = "&#x0024;";
# var defaultView = "grid";
# var expiredFavIDs = null;
# var imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var lessInfoText = "less info";
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var maxResults = 3000;
# var noImageText = "no image";
# var pID = null;
# var postalLat = null;
# var postalLon = null;
# var purveyorCategories = null;
# var searchDistance = null;
# var sectionAbb = "hhh";
# var sectionBase = "hhh";
# var showInfoText = "show info";
# var showMapTabs = 1;
# var showingBanished = 0;
# var showingFavorites = 0;
# var starHint = "save this post in your favorites list";
# var subarea = null;
# var zoomToPosting = null;
# -->
#   </script>
#   <!--[if lt IE 9]>
# <script src="//www.craigslist.org/js/html5shiv.min.js?v=c0739b14a84b052680cdee44fea07435" type="text/javascript" ></script>
#
# <script src="//www.craigslist.org/js/respond-fork.min.js?v=247e877d69233f6f77bff30aca7b5473" type="text/javascript" ></script>
#
# <![endif]-->
#   <!--[if lte IE 7]>
# <script src="//www.craigslist.org/js/json2.min.js?v=6e47a4bb061d538548771024390aa00b" type="text/javascript" ></script>
#
# <![endif]-->
#   <script type="text/javascript">
#    <!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# -->
#   </script>
#   <section class="page-container" id="page-top">
#    <div class="bglogo">
#    </div>
#    <header class="global-header wide">
#     <a class="header-logo" href="/" name="logoLink">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <form action="/search/hhh" class="breadcrumbs-form" data-action="/search/###/hhh" id="breadcrumbform" method="get">
#       <input name="sort" type="hidden" value="rel"/>
#       <input name="query" type="hidden" value="New York City"/>
#       <ul class="breadcrumbs ">
#        <li class="crumb area">
#         <span class="no-js">
#          <a href="/">
#           new york
#          </a>
#         </span>
#         <select class="js-only" id="areaAbb" name="areaAbb">
#          <option value="newyork">
#           new york
#          </option>
#          <option value="albany">
#           albany, NY
#          </option>
#          <option value="allentown">
#           allentown
#          </option>
#          <option value="altoona">
#           altoona
#          </option>
#          <option value="annapolis">
#           annapolis
#          </option>
#          <option value="baltimore">
#           baltimore
#          </option>
#          <option value="binghamton">
#           binghamton
#          </option>
#          <option value="boston">
#           boston
#          </option>
#          <option value="capecod">
#           cape cod
#          </option>
#          <option value="catskills">
#           catskills
#          </option>
#          <option value="cnj">
#           central NJ
#          </option>
#          <option value="chambersburg">
#           cumberland val
#          </option>
#          <option value="delaware">
#           delaware
#          </option>
#          <option value="newlondon">
#           eastern CT
#          </option>
#          <option value="easternshore">
#           eastern shore
#          </option>
#          <option value="martinsburg">
#           eastern WV
#          </option>
#          <option value="elmira">
#           elmira
#          </option>
#          <option value="fingerlakes">
#           finger lakes
#          </option>
#          <option value="frederick">
#           frederick
#          </option>
#          <option value="glensfalls">
#           glens falls
#          </option>
#          <option value="harrisburg">
#           harrisburg
#          </option>
#          <option value="hartford">
#           hartford
#          </option>
#          <option value="hudsonvalley">
#           hudson valley
#          </option>
#          <option value="ithaca">
#           ithaca
#          </option>
#          <option value="jerseyshore">
#           jersey shore
#          </option>
#          <option value="lancaster">
#           lancaster, PA
#          </option>
#          <option value="longisland">
#           long island
#          </option>
#          <option value="newhaven">
#           new haven
#          </option>
#          <option value="newjersey">
#           north jersey
#          </option>
#          <option value="nwct">
#           northwest CT
#          </option>
#          <option value="oneonta">
#           oneonta
#          </option>
#          <option value="philadelphia">
#           philadelphia
#          </option>
#          <option value="poconos">
#           poconos
#          </option>
#          <option value="reading">
#           reading
#          </option>
#          <option value="providence">
#           rhode island
#          </option>
#          <option value="scranton">
#           scranton
#          </option>
#          <option value="southcoast">
#           south coast
#          </option>
#          <option value="southjersey">
#           south jersey
#          </option>
#          <option value="smd">
#           southern MD
#          </option>
#          <option value="pennstate">
#           state college
#          </option>
#          <option value="syracuse">
#           syracuse
#          </option>
#          <option value="utica">
#           utica
#          </option>
#          <option value="washingtondc">
#           washington, DC
#          </option>
#          <option value="westernmass">
#           western mass
#          </option>
#          <option value="williamsport">
#           williamsport
#          </option>
#          <option value="worcester">
#           worcester
#          </option>
#          <option value="york">
#           york, PA
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb subarea">
#         <select id="subArea" name="subArea">
#          <option selected="" value="">
#           all new york
#          </option>
#          <option value="brx">
#           bronx
#          </option>
#          <option value="brk">
#           brooklyn
#          </option>
#          <option value="fct">
#           fairfield
#          </option>
#          <option value="lgi">
#           long island
#          </option>
#          <option value="mnh">
#           manhattan
#          </option>
#          <option value="jsy">
#           new jersey
#          </option>
#          <option value="que">
#           queens
#          </option>
#          <option value="stn">
#           staten island
#          </option>
#          <option value="wch">
#           westchester
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb section">
#         <select id="catAbb" name="catAbb">
#          <option value="ccc">
#           community
#          </option>
#          <option value="eee">
#           events
#          </option>
#          <option value="sss">
#           for sale
#          </option>
#          <option value="ggg">
#           gigs
#          </option>
#          <option selected="" value="hhh">
#           housing
#          </option>
#          <option value="jjj">
#           jobs
#          </option>
#          <option value="rrr">
#           resumes
#          </option>
#          <option value="bbb">
#           services
#          </option>
#         </select>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb category">
#         <select class="js-only" id="subcatAbb">
#          <option value="hhh">
#           all
#          </option>
#          <option value="fee">
#           apts broker fee
#          </option>
#          <option value="nfb">
#           apts broker no fee
#          </option>
#          <option value="abo">
#           apts by owner
#          </option>
#          <option value="hou">
#           apts wanted
#          </option>
#          <option value="swp">
#           housing swap
#          </option>
#          <option value="off">
#           office &amp; commercial
#          </option>
#          <option value="prk">
#           parking &amp; storage
#          </option>
#          <option value="reb">
#           real estate - by broker
#          </option>
#          <option value="reo">
#           real estate - by owner
#          </option>
#          <option value="rew">
#           real estate wanted
#          </option>
#          <option value="roo">
#           rooms &amp; shares
#          </option>
#          <option value="sha">
#           rooms wanted
#          </option>
#          <option value="sbw">
#           sublet/temp wanted
#          </option>
#          <option value="sub">
#           sublets &amp; temporary
#          </option>
#          <option value="vac">
#           vacation rentals
#          </option>
#         </select>
#         <span class="no-js">
#          housing
#         </span>
#         <span class="breadcrumb-arrow">
#          &gt;
#         </span>
#        </li>
#        <li class="crumb no-js">
#         <input type="submit" value="go"/>
#        </li>
#       </ul>
#      </form>
#     </nav>
#     <div class="userlinks">
#      <ul class="user-actions">
#       <li class="user post">
#        <a href="https://post.craigslist.org/c/nyc">
#         post
#        </a>
#       </li>
#       <li class="user account">
#        <a href="https://accounts.craigslist.org/login/home">
#         account
#        </a>
#       </li>
#      </ul>
#      <ul class="user-favs-discards">
#       <li class="user">
#        <div class="favorites">
#         <a class="favlink" href="#">
#          <span aria-hidden="true" class="icon icon-star fav">
#          </span>
#          <span class="fav-number">
#           0
#          </span>
#          <span class="fav-label">
#           favorites
#          </span>
#         </a>
#        </div>
#       </li>
#       <li class="user discards">
#        <form action="/favorites" class="unfavform js-only" method="POST">
#         <div class="to-banish-page">
#          <input class="lastLink" name="lastLink" type="hidden" value="//newyork.craigslist.org/search/hhh?query=New%20York%20City&amp;sort=rel"/>
#          <input class="lastTitle" name="lastTitle" type="hidden" value='new york housing "New York City" - craigslist'/>
#          <input class="unfaves" name="fl" type="hidden"/>
#          <input name="uf" type="hidden" value="1"/>
#          <a class="to-banish-page-link" href="#">
#           <span aria-hidden="true" class="icon icon-trash red">
#           </span>
#           <span class="banished_count">
#            0
#           </span>
#           <span class="discards-label">
#            hidden
#           </span>
#          </a>
#         </div>
#        </form>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <header class="global-header narrow">
#     <a class="header-logo" href="/">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <ul class="breadcrumbs">
#       new york            &gt;
#
# housing
#      </ul>
#     </nav>
#     <span class="linklike show-wide-header">
#      ...
#     </span>
#    </header>
#    <form action="/search/hhh" class="search-form" id="searchform">
#     <div class="querybox">
#      <div class="form-tab js-only">
#       <span class="search-open" title="hide search">
#        «
#       </span>
#       <span class="search-closed" title="show search">
#        »
#       </span>
#      </div>
#      <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search housing" type="text" value="New York City"/>
#      <button class="searchbtn" type="submit">
#       <span aria-hidden="true" class="icon icon-search">
#       </span>
#       <span class="screen-reader-text">
#        press to search craigslist
#       </span>
#      </button>
#      <div class="savealert">
#       <a class="saveme" data-action="save" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Fnewyork%252Ecraigslist%252Eorg%252Fsearch%252Fhhh%253Fquery%253DNew%252520York%252520City%2526sort%253Drel" title="save this search">
#        save search
#       </a>
#      </div>
#     </div>
#     <div class="search-options-container">
#      <h2 class="search-options-header linklike">
#       <div aria-hidden="true" class="icon icon-toggle-gear">
#       </div>
#       options
#       <span class="options-close">
#        close
#       </span>
#      </h2>
#      <input id="excats" name="excats" type="hidden"/>
#      <input name="sort" type="hidden" value="rel"/>
#      <div class="search-options">
#       <div class="searchgroup categories">
#        <div class="cattitle">
#         <a class="reset" href="/search/hhh" title="clear all search parameters">
#          housing
#         </a>
#        </div>
#        <ul class="maincats">
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="off" id="cat_off" name="cat_id" type="checkbox" value="40"/>
#          <a class="category" href="/search/off?query=New%20York%20City&amp;sort=rel">
#           office &amp; commercial
#          </a>
#          <span class="count">
#           18873
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="abo" id="cat_abo" name="cat_id" type="checkbox" value="86"/>
#          <a class="category" href="/search/abo?query=New%20York%20City&amp;sort=rel">
#           apts by owner
#          </a>
#          <span class="count">
#           4578
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="rea" id="cat_rea" name="cat_id" type="checkbox" value="143,144"/>
#          <a class="category" href="/search/rea?query=New%20York%20City&amp;sort=rel">
#           real estate
#          </a>
#          <span class="count">
#           2053
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="roo" id="cat_roo" name="cat_id" type="checkbox" value="18"/>
#          <a class="category" href="/search/roo?query=New%20York%20City&amp;sort=rel">
#           rooms &amp; shares
#          </a>
#          <span class="count">
#           1217
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="nfb" id="cat_nfb" name="cat_id" type="checkbox" value="85"/>
#          <a class="category" href="/search/nfb?query=New%20York%20City&amp;sort=rel">
#           apts broker no fee
#          </a>
#          <span class="count">
#           1182
#          </span>
#         </li>
#         <li class="morecats js-only closed">
#          <span class="linklike closed">
#           <span class="plusminus">
#            +
#           </span>
#           show 9 more
#          </span>
#          <span class="linklike open">
#           <span class="plusminus">
#            –
#           </span>
#           hide 9 more
#          </span>
#          <span class="count">
#           2802
#          </span>
#         </li>
#        </ul>
#        <ul class="othercats closed">
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sub" id="cat_sub" name="cat_id" type="checkbox" value="39"/>
#          <a class="category" href="/search/sub?query=New%20York%20City&amp;sort=rel">
#           sublets &amp; temporary
#          </a>
#          <span class="count">
#           1068
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="fee" id="cat_fee" name="cat_id" type="checkbox" value="60"/>
#          <a class="category" href="/search/fee?query=New%20York%20City&amp;sort=rel">
#           apts broker fee
#          </a>
#          <span class="count">
#           886
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="vac" id="cat_vac" name="cat_id" type="checkbox" value="99"/>
#          <a class="category" href="/search/vac?query=New%20York%20City&amp;sort=rel">
#           vacation rentals
#          </a>
#          <span class="count">
#           535
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="swp" id="cat_swp" name="cat_id" type="checkbox" value="65"/>
#          <a class="category" href="/search/swp?query=New%20York%20City&amp;sort=rel">
#           housing swap
#          </a>
#          <span class="count">
#           133
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="rew" id="cat_rew" name="cat_id" type="checkbox" value="121"/>
#          <a class="category" href="/search/rew?query=New%20York%20City&amp;sort=rel">
#           real estate wanted
#          </a>
#          <span class="count">
#           59
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="hou" id="cat_hou" name="cat_id" type="checkbox" value="2"/>
#          <a class="category" href="/search/hou?query=New%20York%20City&amp;sort=rel">
#           apts wanted
#          </a>
#          <span class="count">
#           41
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="prk" id="cat_prk" name="cat_id" type="checkbox" value="41"/>
#          <a class="category" href="/search/prk?query=New%20York%20City&amp;sort=rel">
#           parking &amp; storage
#          </a>
#          <span class="count">
#           38
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sha" id="cat_sha" name="cat_id" type="checkbox" value="19"/>
#          <a class="category" href="/search/sha?query=New%20York%20City&amp;sort=rel">
#           room/share wanted
#          </a>
#          <span class="count">
#           37
#          </span>
#         </li>
#         <li>
#          <input checked="checked" class="catcheck multi_checkbox" data-abb="sbw" id="cat_sbw" name="cat_id" type="checkbox" value="58"/>
#          <a class="category" href="/search/sbw?query=New%20York%20City&amp;sort=rel">
#           sublet/temp wanted
#          </a>
#          <span class="count">
#           5
#          </span>
#         </li>
#        </ul>
#        <div class="selectall js-only checked">
#         <label>
#          <input checked="checked" class="catcheck selectallcb" type="checkbox"/>
#          <span class="all linklike">
#           select all
#          </span>
#         </label>
#        </div>
#       </div>
#       <input name="userid" type="hidden" value=""/>
#       <div class="searchgroup">
#        <ul>
#         <li>
#          <label class="srchType">
#           <input class="" name="srchType" type="checkbox" value="T"/>
#           search titles only
#          </label>
#         </li>
#         <li>
#          <label class="hasPic">
#           <input class="autosubmit" name="hasPic" type="checkbox" value="1"/>
#           has image
#          </label>
#         </li>
#         <li>
#          <label class="postedToday">
#           <input class="autosubmit" name="postedToday" type="checkbox" value="1"/>
#           posted today
#          </label>
#         </li>
#         <li>
#          <label class="bundleDuplicates">
#           <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1"/>
#           bundle duplicates
#          </label>
#         </li>
#         <li>
#          <label class="searchNearby">
#           <input class="autosubmit" name="searchNearby" type="checkbox" value="1"/>
#           include nearby areas
#          </label>
#         </li>
#        </ul>
#        <ul class="js-only nearbyAreas ">
#         <li class="nearbyZone nearbyZone_3">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_20" name="nearbyArea" type="checkbox" value="59"/>
#           albany, NY
#           <small>
#            (alb)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_7">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_45" name="nearbyArea" type="checkbox" value="355"/>
#           altoona-johnstown
#           <small>
#            (aoo)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_5">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_33" name="nearbyArea" type="checkbox" value="460"/>
#           annapolis, MD
#           <small>
#            (anp)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_4">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_28" name="nearbyArea" type="checkbox" value="34"/>
#           baltimore, MD
#           <small>
#            (bal)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_10">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_60" name="nearbyArea" type="checkbox" value="483"/>
#           belleville, ON
#           <small>
#            (bel)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_3">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_21" name="nearbyArea" type="checkbox" value="248"/>
#           binghamton, NY
#           <small>
#            (bgm)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_5">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_35" name="nearbyArea" type="checkbox" value="4"/>
#           boston
#           <small>
#            (bos)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_9">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_58" name="nearbyArea" type="checkbox" value="40"/>
#           buffalo, NY
#           <small>
#            (buf)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_7">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_42" name="nearbyArea" type="checkbox" value="239"/>
#           cape cod / islands
#           <small>
#            (cap)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_1">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_9" name="nearbyArea" type="checkbox" value="451"/>
#           catskills
#           <small>
#            (cat)
#           </small>
#          </label>
#         </li>
#         <li class="">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_2" name="nearbyArea" type="checkbox" value="349"/>
#           central NJ
#           <small>
#            (cnj)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_10">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_63" name="nearbyArea" type="checkbox" value="290"/>
#           charlottesville, VA
#           <small>
#            (uva)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_10">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_62" name="nearbyArea" type="checkbox" value="452"/>
#           chautauqua, NY
#           <small>
#            (chq)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_10">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_61" name="nearbyArea" type="checkbox" value="481"/>
#           cornwall, ON
#           <small>
#            (ycc)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_6">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_38" name="nearbyArea" type="checkbox" value="705"/>
#           cumberland valley
#           <small>
#            (cbg)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_3">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_19" name="nearbyArea" type="checkbox" value="193"/>
#           delaware
#           <small>
#            (dlw)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_2">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_15" name="nearbyArea" type="checkbox" value="281"/>
#           eastern CT
#           <small>
#            (nlo)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_7">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_44" name="nearbyArea" type="checkbox" value="444"/>
#           eastern panhandle
#           <small>
#            (ewv)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_4">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_29" name="nearbyArea" type="checkbox" value="328"/>
#           eastern shore
#           <small>
#            (esh)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_5">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_30" name="nearbyArea" type="checkbox" value="453"/>
#           elmira-corning
#           <small>
#            (elm)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_6">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_36" name="nearbyArea" type="checkbox" value="685"/>
#           finger lakes, NY
#           <small>
#            (fgl)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_6">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_39" name="nearbyArea" type="checkbox" value="633"/>
#           frederick, MD
#           <small>
#            (fdk)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_8">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_49" name="nearbyArea" type="checkbox" value="457"/>
#           fredericksburg, VA
#           <small>
#            (ezf)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_5">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_34" name="nearbyArea" type="checkbox" value="686"/>
#           glens falls, NY
#           <small>
#            (gfl)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_3">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_23" name="nearbyArea" type="checkbox" value="166"/>
#           harrisburg, PA
#           <small>
#            (hrs)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_10">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_64" name="nearbyArea" type="checkbox" value="447"/>
#           harrisonburg, VA
#           <small>
#            (shd)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_2">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_12" name="nearbyArea" type="checkbox" value="44"/>
#           hartford, CT
#           <small>
#            (htf)
#           </small>
#          </label>
#         </li>
#         <li class="">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_4" name="nearbyArea" type="checkbox" value="249"/>
#           hudson valley, NY
#           <small>
#            (hud)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_5">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_31" name="nearbyArea" type="checkbox" value="201"/>
#           ithaca, NY
#           <small>
#            (ith)
#           </small>
#          </label>
#         </li>
#         <li class="">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_1" name="nearbyArea" type="checkbox" value="561"/>
#           jersey shore
#           <small>
#            (jys)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_9">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_54" name="nearbyArea" type="checkbox" value="385"/>
#           kingston, ON
#           <small>
#            (kng)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_2">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_17" name="nearbyArea" type="checkbox" value="279"/>
#           lancaster, PA
#           <small>
#            (lns)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_1">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_7" name="nearbyArea" type="checkbox" value="167"/>
#           lehigh valley
#           <small>
#            (alt)
#           </small>
#          </label>
#         </li>
#         <li class="">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_3" name="nearbyArea" type="checkbox" value="250"/>
#           long island, NY
#           <small>
#            (isp)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_7">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_46" name="nearbyArea" type="checkbox" value="198"/>
#           new hampshire
#           <small>
#            (nhm)
#           </small>
#          </label>
#         </li>
#         <li class="">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_5" name="nearbyArea" type="checkbox" value="168"/>
#           new haven, CT
#           <small>
#            (hvn)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_9">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_59" name="nearbyArea" type="checkbox" value="48"/>
#           norfolk / hampton roads
#           <small>
#            (nfk)
#           </small>
#          </label>
#         </li>
#         <li class="">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_0" name="nearbyArea" type="checkbox" value="170"/>
#           north jersey
#           <small>
#            (njy)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_1">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_10" name="nearbyArea" type="checkbox" value="354"/>
#           northwest CT
#           <small>
#            (nct)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_3">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_18" name="nearbyArea" type="checkbox" value="684"/>
#           oneonta, NY
#           <small>
#            (onh)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_1">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_8" name="nearbyArea" type="checkbox" value="17"/>
#           philadelphia
#           <small>
#            (phi)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_9">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_55" name="nearbyArea" type="checkbox" value="338"/>
#           plattsburgh-adirondacks
#           <small>
#            (plb)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_1">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_6" name="nearbyArea" type="checkbox" value="356"/>
#           poconos
#           <small>
#            (poc)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_9">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_56" name="nearbyArea" type="checkbox" value="683"/>
#           potsdam-canton-massena
#           <small>
#            (ptd)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_2">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_14" name="nearbyArea" type="checkbox" value="278"/>
#           reading, PA
#           <small>
#            (rea)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_4">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_24" name="nearbyArea" type="checkbox" value="38"/>
#           rhode island
#           <small>
#            (prv)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_9">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_57" name="nearbyArea" type="checkbox" value="60"/>
#           richmond, VA
#           <small>
#            (ric)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_8">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_50" name="nearbyArea" type="checkbox" value="126"/>
#           rochester, NY
#           <small>
#            (rcs)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_1">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_11" name="nearbyArea" type="checkbox" value="276"/>
#           scranton / wilkes-barre
#           <small>
#            (avp)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_4">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_27" name="nearbyArea" type="checkbox" value="378"/>
#           south coast, MA
#           <small>
#            (sma)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_2">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_13" name="nearbyArea" type="checkbox" value="286"/>
#           south jersey
#           <small>
#            (snj)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_7">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_43" name="nearbyArea" type="checkbox" value="556"/>
#           southern maryland
#           <small>
#            (smd)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_6">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_40" name="nearbyArea" type="checkbox" value="277"/>
#           state college, PA
#           <small>
#            (psu)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_6">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_37" name="nearbyArea" type="checkbox" value="130"/>
#           syracuse, NY
#           <small>
#            (syr)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_8">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_53" name="nearbyArea" type="checkbox" value="704"/>
#           twin tiers NY/PA
#           <small>
#            (tts)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_5">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_32" name="nearbyArea" type="checkbox" value="247"/>
#           utica-rome-oneida
#           <small>
#            (uti)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_8">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_52" name="nearbyArea" type="checkbox" value="93"/>
#           vermont
#           <small>
#            (brl)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_6">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_41" name="nearbyArea" type="checkbox" value="10"/>
#           washington, DC
#           <small>
#            (wdc)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_8">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_48" name="nearbyArea" type="checkbox" value="337"/>
#           watertown, NY
#           <small>
#            (wtn)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_8">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_51" name="nearbyArea" type="checkbox" value="329"/>
#           western maryland
#           <small>
#            (wmd)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_2">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_16" name="nearbyArea" type="checkbox" value="173"/>
#           western massachusetts
#           <small>
#            (wma)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_4">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_26" name="nearbyArea" type="checkbox" value="463"/>
#           williamsport, PA
#           <small>
#            (wpt)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_7">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_47" name="nearbyArea" type="checkbox" value="711"/>
#           winchester, VA
#           <small>
#            (okv)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_4">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_25" name="nearbyArea" type="checkbox" value="240"/>
#           worcester / central MA
#           <small>
#            (wor)
#           </small>
#          </label>
#         </li>
#         <li class="nearbyZone nearbyZone_3">
#          <label class="nearby">
#           <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_22" name="nearbyArea" type="checkbox" value="357"/>
#           york, PA
#           <small>
#            (yrk)
#           </small>
#          </label>
#         </li>
#         <li>
#          <span class="nextNearbyZone linklike" data-zone="1">
#           + show
#           <span id="nearbyNumber">
#            65
#           </span>
#           more...
#          </span>
#         </li>
#        </ul>
#       </div>
#       <div class="searchgroup">
#        <span class="searchfieldlabel">
#         miles from zip
#        </span>
#        <input class="flatinput searchInput search_distance" inputmode="numeric" max="200" min="0" name="search_distance" placeholder="miles" size="3" type="number" value=""/>
#        <input class="flatinput searchInput postal" name="postal" placeholder="from zip" size="7" type="text" value=""/>
#       </div>
#       <div class="searchgroup minmax ">
#        <span class="searchfieldlabel">
#         price
#        </span>
#        <input class="flatinput min" name="min_price" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
#        <input class="flatinput max" name="max_price" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
#       </div>
#       <div class="searchgroup bed-bath-selects">
#        <span class="searchfieldlabel">
#         bedrooms
#        </span>
#        <select class="autosubmit" name="min_bedrooms">
#         <option value="">
#          min
#         </option>
#         <option value="1">
#          1
#         </option>
#         <option value="2">
#          2
#         </option>
#         <option value="3">
#          3
#         </option>
#         <option value="4">
#          4
#         </option>
#         <option value="5">
#          5
#         </option>
#         <option value="6">
#          6
#         </option>
#         <option value="7">
#          7
#         </option>
#         <option value="8">
#          8
#         </option>
#        </select>
#        -
#        <select class="autosubmit" name="max_bedrooms">
#         <option value="">
#          max
#         </option>
#         <option value="1">
#          1
#         </option>
#         <option value="2">
#          2
#         </option>
#         <option value="3">
#          3
#         </option>
#         <option value="4">
#          4
#         </option>
#         <option value="5">
#          5
#         </option>
#         <option value="6">
#          6
#         </option>
#         <option value="7">
#          7
#         </option>
#         <option value="8">
#          8
#         </option>
#        </select>
#       </div>
#       <div class="searchgroup bed-bath-selects">
#        <span class="searchfieldlabel">
#         bathrooms
#        </span>
#        <select class="autosubmit" name="min_bathrooms">
#         <option value="">
#          min
#         </option>
#         <option value="1">
#          1
#         </option>
#         <option value="2">
#          2
#         </option>
#         <option value="3">
#          3
#         </option>
#         <option value="4">
#          4
#         </option>
#         <option value="5">
#          5
#         </option>
#         <option value="6">
#          6
#         </option>
#         <option value="7">
#          7
#         </option>
#         <option value="8">
#          8
#         </option>
#        </select>
#        -
#        <select class="autosubmit" name="max_bathrooms">
#         <option value="">
#          max
#         </option>
#         <option value="1">
#          1
#         </option>
#         <option value="2">
#          2
#         </option>
#         <option value="3">
#          3
#         </option>
#         <option value="4">
#          4
#         </option>
#         <option value="5">
#          5
#         </option>
#         <option value="6">
#          6
#         </option>
#         <option value="7">
#          7
#         </option>
#         <option value="8">
#          8
#         </option>
#        </select>
#       </div>
#       <div class="searchgroup minmax ">
#        <span class="searchfieldlabel">
#         ft
#         <sup>
#          2
#         </sup>
#        </span>
#        <input class="flatinput min" name="minSqft" placeholder="min" title="whole number, no letters or symbols" type="tel" value=""/>
#        <input class="flatinput max" name="maxSqft" placeholder="max" title="whole number, no letters or symbols" type="tel" value=""/>
ft
#           <sup>
#            2
#           </sup>
#           -
#          </span>
#          <span class="result-hood">
#           (Midtown West)
#          </span>
#          <span class="result-tags">
#           pic
#           <span class="maptag" data-pid="6658707207">
#            map
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#      </ul>
#     </div>
#     <div class="search-legend bottom">
#      <div class="search-view">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="search-sort">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="paginator buttongroup firstpage">
#       <span class="resulttotal">
#        <span class="for-map">
#         displaying
#         <span class="displaycountShow">
#          ...
#         </span>
#         postings
#        </span>
#       </span>
#       <span class="buttons">
#        <a class="button first" href="/search/hhh?query=New%20York%20City&amp;sort=rel" title="first page">
#         &lt;&lt;
#        </a>
#        <span class="button first" title="first page">
#         &lt;&lt;
#        </span>
#        <a class="button prev" href="/search/hhh?query=New%20York%20City&amp;sort=rel" title="previous page">
#         &lt; prev
#        </a>
#        <span class="button prev" title="previous page">
#         &lt; prev
#        </span>
#        <span class="button pagenum">
#         <span class="range">
#          <span class="rangeFrom">
#           1
#          </span>
#          -
#          <span class="rangeTo">
#           120
#          </span>
#         </span>
#         /
#         <span class="totalcount">
#          3000
#         </span>
#        </span>
#        <a class="button next" href="/search/hhh?s=120&amp;query=New%20York%20City&amp;sort=rel" title="next page">
#         next &gt;
#        </a>
#        <span class="button next" title="next page">
#         next &gt;
#        </span>
#       </span>
#      </div>
#     </div>
#     <section class="blurbs">
#     </section>
#     <div id="floater">
#      <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif"/>
#      <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif"/>
#     </div>
#    </form>
#    <div class="slidemessage">
#     <span class="fave">
#      <span class="star">
#      </span>
#      favorited
#     </span>
#     <span class="unfave">
#      <span class="star">
#      </span>
#      no longer favorited
#     </span>
#     <span class="hide">
#      <span class="trash">
#      </span>
#      hidden
#     </span>
#     <span class="unhide">
#      <span class="trash">
#      </span>
#      no longer hidden
#     </span>
#    </div>
#    <footer>
#     <span class="rss">
#      <a class="l" href="https://newyork.craigslist.org/search/hhh?format=rss&amp;query=New%20York%20City&amp;sort=rel">
#       RSS
#      </a>
#      <a href="https://www.craigslist.org/about/rss">
#       (?)
#      </a>
#      <br/>
#     </span>
#     <ul class="clfooter">
#      <li>
#       ©
#       <span class="desktop">
#        craigslist
#       </span>
#       <span class="mobile">
#        CL
#       </span>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/help/">
#        help
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/scams">
#        safety
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/privacy.policy">
#        privacy
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://forums.craigslist.org/?forumID=8">
#        feedback
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/craigslist_is_hiring">
#        cl jobs
#       </a>
#      </li>
#      <li>
#       <a href="//www.craigslist.org/about/terms.of.use.en">
#        terms
#       </a>
#       <sup class="neu">
#        new
#       </sup>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/">
#        about
#       </a>
#      </li>
#      <li class="fsel desktop linklike" data-mode="mobile">
#       mobile
#      </li>
#      <li class="fsel mobile linklike" data-mode="regular">
#       desktop
#      </li>
#     </ul>
#    </footer>
#   </section>
#   <template id="gallerycarousel">
#    <div class="slider-info">
#    </div>
#    <div class="slider-back arrow">
#     &lt;
#    </div>
#    <div class="slider-forward arrow">
#     &gt;
#    </div>
#   </template>
#   <script src="//www.craigslist.org/js/general-concat.min.js?v=54195bc79edc43749a4c3a4cc821368c" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--
#         var iframe = document.createElement('iframe');
#         iframe.style.display = 'none';
#         iframe.src = '//www.' + CL.url.baseDomain + '/static/localstorage.html?v=51a29e41f8e978141e4085ed4a77d170';
#         document.body.insertBefore(iframe, null);
#     -->
#   </script>
#   <script id="clustertemplate" type="text/template">
#    <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     unhide
#                 </span>
#             </span>
#         </div>
#     </li>
#   </script>
#   <script id="postingtemplate" type="text/template">
#    <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">hide this posting</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">unhide</span>
#                         unhide
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lt;</span><span class="slider-info"></span><span class="slider-forward arrow">&gt;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <div class="timecontainer"></div>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
#   </script>
#   <script id="popuptemplate" type="text/template">
#    <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
#   </script>
#   <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=302c05f90f7874636d36a1d9f65d3d9e" type="text/javascript">
#   </script>
#   <script src="//www.craigslist.org/js/search-concat.min.js?v=85526739da0e908f5ac380a3b4a4271a" type="text/javascript">
#   </script>
#   <script src="//www.craigslist.org/js/postings-concat.min.js?v=bd463bab99d7d8cfe87cfb207de0682a" type="text/javascript">
#   </script>
#  </body>
# </html>

# %% [markdown]
# #### check a single listing

# %%
listings=soup.find('li',class_='result-row')

# %%
print(listings.prettify())
# Out:
# <li class="result-row" data-pid="6640183142" data-repost-of="4723117692">
#  <a class="result-image gallery" data-ids="1:00m0m_M22co7Crkb,1:00808_c6Uc0vzB4pZ,1:00k0k_dif4AM2ez0B,1:00D0D_2AvPMhidzaI,1:00303_eCo6bYe5G2W,1:00b0b_g64EAtIXGja,1:01313_aK46xxMBHx,1:00H0H_gLzUJj4LXpQ" href="https://newyork.craigslist.org/mnh/abo/d/real-2-bds-1baths-wd-in-the/6640183142.html">
#   <span class="result-price">
#    $4600
#   </span>
#  </a>
#  <p class="result-info">
#   <span class="icon icon-star" role="button">
#    <span class="screen-reader-text">
#     favorite this post
#    </span>
#   </span>
#   <time class="result-date" datetime="2018-07-31 19:18" title="Tue 31 Jul 07:18:29 PM">
#    Jul 31
#   </time>
#   <a class="result-title hdrlnk" data-id="6640183142" href="https://newyork.craigslist.org/mnh/abo/d/real-2-bds-1baths-wd-in-the/6640183142.html">
#    ► REAL 2 BDS/ 1BATHS  ___ W.D IN THE UNIT ____ 3RD AVE   ___NO FEE
#   </a>
#   <span class="result-meta">
#    <span class="result-price">
#     $4600
#    </span>
#    <span class="housing">
#     2br -
#    </span>
#    <span class="result-hood">
#     (Nolita / Bowery)
#    </span>
#    <span class="result-tags">
#     pic
#     <span class="maptag" data-pid="6640183142">
#      map
#     </span>
#    </span>
#    <span class="banish icon icon-trash" role="button">
#     <span class="screen-reader-text">
#      hide this posting
#     </span>
#    </span>
#    <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#    </span>
#    <a class="restore-link" href="#">
#     <span class="restore-narrow-text">
#      restore
#     </span>
#     <span class="restore-wide-text">
#      restore this posting
#     </span>
#    </a>
#   </span>
#  </p>
# </li>

# %%
price=listings.find('span',class_='result-price')
price.text
# Out:
# '$4600'

# %%
#listings.find('a',class_="result-image gallery")
link=listings.a['href']
#link=link.split(' ')
link
# Out:
# 'https://newyork.craigslist.org/mnh/abo/d/real-2-bds-1baths-wd-in-the/6640183142.html'

# %%
description=listings.find('span',class_='housing')
description.text.strip().replace(' ','').replace('-\n',' ').replace('-','')
# Out:
# '2br'

# %%
title=listings.find('a',class_="result-title hdrlnk").text
title
# Out:
# '► REAL 2 BDS/ 1BATHS  ___ W.D IN THE UNIT ____ 3RD AVE   ___NO FEE'

# %%
post_time=listings.time.text
post_time
# Out:
# 'Jul 31'

# %% [markdown]
# ### Create a loop to get all the price, description, link and post time of the house listings

# %%
import numpy as np
price=[]
website=[]
description=[]
title=[]
post_time=[]

city=['New York City','White Plains','Queens','Yonkers']
for city in city:
    #url='https://newyork.craigslist.org/search/rea?query=long+island+city+apartment&availabilityMode=0&sale_date=all+dates
    url='https://newyork.craigslist.org/search/hhh?sort=rel&query={}'.format(city.replace(' ','+'))
    source=requests.get(url).text
    soup=BeautifulSoup(source,'lxml')
    for listings in soup.find_all('li',class_='result-row'):
        #price.append(listings.find('span',class_='result-price').text)
        if listings.find('span',class_='result-price') is not None:
            price.append(listings.find('span',class_='result-price').text)
        else:
            price.append(np.NaN)
        if listings.find('span',class_='result-price') is not None:
            title.append(listings.find('a',class_="result-title hdrlnk").text)
        else:
            title.append(np.NaN)
        website.append(listings.a['href'])
        desc=listings.find('span',class_='housing')
        if desc is not None:
            description.append(desc.text.strip().replace(' ','').replace('-\n',' ').replace('-',''))
        else:
            description.append(np.NaN)
        post_time.append(listings.time.text)

# %% [markdown]
# ### output to a pandas dataframe

# %%
import pandas as pd
pd.options.display.max_colwidth=1000 # to display full url link
#pd.set_option('display.width', 1000)
dataframe=pd.DataFrame({'description':description, 'website':website, 'price':price, 'post_time':post_time,'Title':title})

# %%
dataframe
# Out:
#                                                                      Title  \
# 0      Private Offices - NEW, Clean, Fully Serviced, Furnished, AFFORDABLE
# 1    Victorian T-House on upper 5th Ave. gutted*CAIR*WD*BALC*FP* E+W TRAIN
# 2      Queen-sized bedroom in newly renovated 2br/1 bath in Lincoln Square
# 3                                                                      NaN
# 4               Furnished Upper West Side 1 Bedroom Apt in Luxury Building
# 5        n,,1 br apt located on corner of 105 st and Amsterdam ave,laundry
# 6                     Looking for an enjoyable roommate for single bedroom
# 7               *NO FEE* Real Three Bedroom-Doorman-GYM-Laundry-Prime Fidi
# 8             NO FEE Attended Doorman Located on the Corner of Madison Ave
# 9                 Windows Throughout Combined Units Madison & 33 st NO FEE
# 10                       NO FEE DOORMAN BUILDING NEAR PENN/ PORT AUTHORITY
# 11                   ROOMS AVAILABLE WASHINGTON HEIGHTS $1000 SEPT MOVE IN
# 12                       NO FEE DOORMAN BUILDING NEAR PENN/ PORT AUTHORITY
# 13     FULL 2ND FLOOR 2BR/2BA @ 140th St. / Amsterdam / CCNY / W/D in unit
# 14    Bright One Br w/Treetop Views, Open House by App't Wed Aug 1st 6-7pm
# 15       ALL NEW - Private Offices - 1 Block From Grand Central - ONLY 805
# 16                   STUDIO GYM-VALET-DOORMAN- PRIME FiDi LOCATION*NO FEE*
# 17              w112@ BDWY, bright, renovated, beautiful studio apartment.
# 18               $ 64 / SF ↣ No Fee! - Times Square Office Space For Rent!
# 19                                                                     NaN
# 20          NO FEE Beautiful Attended 24/7 Lobby + Great Staff! 1400 SQ FT
# 21            NO FEE Attended Doorman Located on the Corner of Madison Ave
# 22            NO FEE Attended Doorman Located on the Corner of Madison Ave
# 23                   Reno 2 bdrm,Backyard,laundry,D/N/R train, A/C! no fee
# 24         Grand Central Private Offices - ALL NEW EVERYTHING - Call Today
# 25         Fully furnished One Bedroom with all new finishes, top location
# 26                      NO FEE With Windows Facing Madison and 33rd street
# 27            NO FEE Attended Doorman Located on the Corner of Madison Ave
# 28            NO FEE Attended Doorman Located on the Corner of Madison Ave
# 29                                             10-12 Windowed Office Space
# ..                                                                     ...
# 450                                               STUDIO IN QUIET BUILDING
# 451                                                         LEGAL 6 FAMILY
# 452                                                                    NaN
# 453                                                  TWO FAMILY TOWN HOUSE
# 454                                           GREAT 2 FAMILY NEW TO MARKET
# 455                                          WINCHESTER VILLAGE TOWN HOUSE
# 456                                                THREE FAMILY INVESTMENT
# 457                                           BEAUTIFUL SINGLE FAMILY HOME
# 458                                       LARGE SPACIOUS CORNER TWO FAMILY
# 459                                          GARDEN STYLE STUDIO APARTMENT
# 460                                   PRICED REDUCED***   HANDYMAN SPECIAL
# 461                                         REASONABLE INVESTMENT PROPERTY
# 462                                                     THREE BEDROOM CAPE
# 463                                           BRICK THREE BEDROOM COLONIAL
# 464                                                    INDUSTRIAL BUILDING
# 465                                    LARGE JUNIOR FOUR CENTRALLY LOCATED
# 466                                             ONE BEDROOM WITH A BALCONY
# 467                                                        SPACIOUS DUPLEX
# 468                                        NESTLED IN THE HEART OF YONKERS
# 469                                 SPACIOUS 5 BEDROOM SINGLE FAMILY HOUSE
# 470                                                     MIXED USE PROPERTY
# 471                FOUR FAMILY WITH ADDITIONAL BUILDINGS AS A PACKAGE DEAL
# 472                                          THREE BEDROOM RANCH ALL BRICK
# 473                                                      6 FAMILY BUILDING
# 474                                           FULLY RENOVATED THREE FAMILY
# 475                                    THREE BEDROOM CONDO: WEST GATE PARK
# 476                          STUDIO UNIT FOR SALE AT 23 WATER GRANT STREET
# 477                            SPACIOUS STUDIO IN PARKVIEW OWNERS BUILDING
# 478                                REMSEN GARDENS ONE BEDROOM UNIT FORSALE
# 479                                   TWO BEDROOM IN GRASSY SPRAIN GARDENS
#
#      description post_time     price  \
# 0         200ft2    Jul 31      $650
# 1            2br    Jul 31     $2995
# 2         650ft2    Jul 31     $2057
# 3            NaN    Jul 31       NaN
# 4     1br 800ft2    Jul 31     $4500
# 5            1br    Jul 31     $2399
# 6            NaN    Jul 31     $1293
# 7            NaN    Jul 31     $4100
# 8         560ft2    Jul 31     $2250
# 9         560ft2    Jul 31     $2250
# 10        800ft2    Jul 31     $2650
# 11           NaN    Jul 31     $1000
# 12        800ft2    Jul 31     $2650
# 13   2br 1300ft2    Jul 31     $3100
